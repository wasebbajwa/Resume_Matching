# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn import utils
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
# !pip install gensim==3.8.3
from gensim.models.doc2vec import TaggedDocument
from gensim.models import Doc2Vec
from tqdm import tqdm
import os
from collections import Counter
from gensim.models import KeyedVectors
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Requirement already satisfied: gensim==3.8.3 in /usr/local/lib/python3.7/dist-packages (3.8.3)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.3) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.3) (1.15.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.3) (5.2.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.3) (1.19.5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Prepare final data set

# %%
fol_dir='/content/drive/MyDrive/NLP/'

# %%
df_names=os.listdir(fol_dir+'data-data_sets') #get file names
df_final=pd.DataFrame() #create an empty data frame
###join data sets##
for df_name in df_names:
    df=pd.read_csv(fol_dir+'data-data_sets/'+df_name)
    df_final=pd.concat([df_final, df], axis=0,ignore_index=True)
###################

# %%
df_final.head()
# Out:
#                                            Job Title  ... Preferred Qualifications
# 0                Senior Data Scientist - Telecommute  ...                      NaN
# 1  Senior Principal Data Scientist - Telecommute ...  ...                      NaN
# 2                       Data Scientist - Telecommute  ...                      NaN
# 3                       Data Scientist - Telecommute  ...                      NaN
# 4             Data Scientist, Optum360 - Telecommute  ...                      NaN
#
# [5 rows x 6 columns]

# %%
df_final.columns
# Out:
# Index(['Job Title', 'Description', 'Responsibilities', 'Basic Qualifications',
#        'Preffered Qualifications', 'Preferred Qualifications'],
#       dtype='object')

# %% [markdown]
# 'Preffered Qualifications' and 'Preferred Qualifications' are two duplicated columns.So, these two columns should be combined

# %%
df_final["Preffered Qualifications"].fillna("", inplace = True) #replace NULL values with spaces
df_final['Preferred Qualifications'].fillna("", inplace = True) #replace NULL values with spaces
df_final['Preferred Qualifications']=df_final['Preffered Qualifications']+df_final['Preferred Qualifications'] #combine two columns
df_final=df_final.drop(['Preffered Qualifications'], axis = 1) #drop one column

# %%
df_final.head()
# Out:
#                                            Job Title  ...                           Preferred Qualifications
# 0                Senior Data Scientist - Telecommute  ...  Preferred Qualifications\n Master’s degree in ...
# 1  Senior Principal Data Scientist - Telecommute ...  ...  Master’s Degree or higher in a highly quantita...
# 2                       Data Scientist - Telecommute  ...  BS in science, applied mathematics, (bio) stat...
# 3                       Data Scientist - Telecommute  ...  Experience with health care claims data\nExper...
# 4             Data Scientist, Optum360 - Telecommute  ...  Master’s degree\nHealth care industry experien...
#
# [5 rows x 5 columns]

# %%
df_final['ID']=[i+1 for i in range(len(df_final))] #create a ID column. ID is unique for each job
df_final=df_final[['ID','Job Title', 'Description', 'Responsibilities', 'Basic Qualifications',
       'Preferred Qualifications']] #

# %%
df_final.head()
# Out:
#    ID  ...                           Preferred Qualifications
# 0   1  ...  Preferred Qualifications\n Master’s degree in ...
# 1   2  ...  Master’s Degree or higher in a highly quantita...
# 2   3  ...  BS in science, applied mathematics, (bio) stat...
# 3   4  ...  Experience with health care claims data\nExper...
# 4   5  ...  Master’s degree\nHealth care industry experien...
#
# [5 rows x 6 columns]

# %%
df_final.to_csv(fol_dir+'data-total_job_posting.csv',index=False) #save joined file

# %% [markdown]
# # Data Preprocessing

# %%
df=pd.read_csv(fol_dir+'data-total_job_posting.csv') #load the combined data set

# %%
df.head()
# Out:
#    ID  ...                           Preferred Qualifications
# 0   1  ...  Preferred Qualifications\n Master’s degree in ...
# 1   2  ...  Master’s Degree or higher in a highly quantita...
# 2   3  ...  BS in science, applied mathematics, (bio) stat...
# 3   4  ...  Experience with health care claims data\nExper...
# 4   5  ...  Master’s degree\nHealth care industry experien...
#
# [5 rows x 6 columns]

# %%
print(df['Description'][0])
print('*************************')
print(df['Responsibilities'][0])
print('*************************')
print(df['Basic Qualifications'][0])
print('*************************')
print(df['Preferred Qualifications'][0])
# Out:
# Combine two of the fastest-growing fields on the planet with a culture of performance, collaboration and opportunity and this is what you get. Leading edge technology in an industry that's improving the lives of millions. Here, innovation isn't about another gadget, it's about making health care data available wherever and whenever people need it, safely and reliably. There's no room for error. Join us and start doing your life's best work.(sm)
#
#  The Consumer Pricing, Analytics & Reporting Team (CPAR) within OptumRx uses sophisticated algorithms and techniques to understand, quantify and inform our product lines of business, operations and leaders with practical insights for improving their services and operations in support of a world-class OptumRx Consumer Experience. The team uses a blend of scientific, problem solving, and quantitative skills to develop and deliver groundbreaking methods addressing critical problems in our digital environment. The CPAR team collaborates across product, design, engineer, and IT teams through data science, machine learning, and AI.
#
#  Do you want to be part of a growing data science and data engineering team that is helping to shape the digital experiences for millions of customers? As a Senior Data Scientist, you will work cross-functionally with other data scientists, analysts, business leaders, and product managers to design, develop, and deploy state-of-the-art models, insights & tools that make a meaningful difference to millions of our customers. You will glean actionable insights from Optum’s vast trove of data to translate business problems into predictive models.
#
#  This is a unique, high visibility opportunity for someone who wants to have a business impact, dive deep into large-scale data analyses machine learning, reinforcement learning, enable measurable actions and work closely with product and operations teams. This position will report directly to the CPAR Director.
# *************************
# Lead and deliver data science solutions leveraging the latest machine learning techniques, including exploratory data analysis, feature engineering, and selection, model selection, evaluation, and cross-validation, a deployment that operationalizes at scale and that drives value to OptumRx
#  Research and apply a range of data science methodologies and machine learning models to complex business problems
#  Develop, implement, and maintain tools and algorithms using Python and/or other languages with appropriate libraries and frameworks
#  Communicate results as well as their uncertainty and limitations effectively to technical and non-technical stakeholders
# *************************
# Bachelor’s degree in statistics, mathematics, computer science, engineering, or related discipline
#  3+ years of relevant real-world experience researching, developing, and delivering high impact data-driven insights through machine learning
#  3+ years of experience using exploratory data analysis, data profiling, and feature engineering on large structured and unstructured datasets
#  Hands-on, demonstrable computer programming skill in SQL, Python, R, or similar programming language
#  Solid communication skills - ability to succinctly communicate results and tell compelling stories with data to any audience (e.g. presenting findings and deep dives to senior leadership)
# *************************
# Preferred Qualifications
#  Master’s degree in statistics, mathematics, computer science, engineering, or related discipline
#  Deep knowledge of probability, statistics, and machine learning algorithms with the ability to determine when to apply them
#  Deep understanding of supervised and unsupervised machine learning techniques
#  Knowledge of Azure, or similar cloud platforms
#  Experience presenting to both technical and non-technical audiences and history of publications or presentations at conferences

# %%
###replace NULL values with empty spaces###
df["Description"].fillna(" ", inplace = True)
df["Responsibilities"].fillna(" ", inplace = True)
df['Basic Qualifications'].fillna(" ", inplace = True)
df['Preferred Qualifications'].fillna(" ", inplace = True)

# %%
#create full job discriptions. These discriptions will be used to train the doc2vec model
df["full_job_description"]=df["Description"]+' '+df["Responsibilities"]+' '+df['Basic Qualifications']+' '+df['Preferred Qualifications']

# %%
#replace '\n',',','/' with spaces
df["full_job_description"]=df["full_job_description"].replace('\n',' ', regex=True)
df["full_job_description"]=df["full_job_description"].replace(',',' ', regex=True)
df["full_job_description"]=df["full_job_description"].replace('/',' ', regex=True)

# %%
df["full_job_description"][0]
# Out:
# "Combine two of the fastest-growing fields on the planet with a culture of performance  collaboration and opportunity and this is what you get. Leading edge technology in an industry that's improving the lives of millions. Here  innovation isn't about another gadget  it's about making health care data available wherever and whenever people need it  safely and reliably. There's no room for error. Join us and start doing your life's best work.(sm)    The Consumer Pricing  Analytics & Reporting Team (CPAR) within OptumRx uses sophisticated algorithms and techniques to understand  quantify and inform our product lines of business  operations and leaders with practical insights for improving their services and operations in support of a world-class OptumRx Consumer Experience. The team uses a blend of scientific  problem solving  and quantitative skills to develop and deliver groundbreaking methods addressing critical problems in our digital environment. The CPAR team collaborates across product  design  engineer  and IT teams through data science  machine learning  and AI.    Do you want to be part of a growing data science and data engineering team that is helping to shape the digital experiences for millions of customers? As a Senior Data Scientist  you will work cross-functionally with other data scientists  analysts  business leaders  and product managers to design  develop  and deploy state-of-the-art models  insights & tools that make a meaningful difference to millions of our customers. You will glean actionable insights from Optum’s vast trove of data to translate business problems into predictive models.    This is a unique  high visibility opportunity for someone who wants to have a business impact  dive deep into large-scale data analyses machine learning  reinforcement learning  enable measurable actions and work closely with product and operations teams. This position will report directly to the CPAR Director. Lead and deliver data science solutions leveraging the latest machine learning techniques  including exploratory data analysis  feature engineering  and selection  model selection  evaluation  and cross-validation  a deployment that operationalizes at scale and that drives value to OptumRx  Research and apply a range of data science methodologies and machine learning models to complex business problems  Develop  implement  and maintain tools and algorithms using Python and or other languages with appropriate libraries and frameworks  Communicate results as well as their uncertainty and limitations effectively to technical and non-technical stakeholders Bachelor’s degree in statistics  mathematics  computer science  engineering  or related discipline  3+ years of relevant real-world experience researching  developing  and delivering high impact data-driven insights through machine learning  3+ years of experience using exploratory data analysis  data profiling  and feature engineering on large structured and unstructured datasets  Hands-on  demonstrable computer programming skill in SQL  Python  R  or similar programming language  Solid communication skills - ability to succinctly communicate results and tell compelling stories with data to any audience (e.g. presenting findings and deep dives to senior leadership) Preferred Qualifications  Master’s degree in statistics  mathematics  computer science  engineering  or related discipline  Deep knowledge of probability  statistics  and machine learning algorithms with the ability to determine when to apply them  Deep understanding of supervised and unsupervised machine learning techniques  Knowledge of Azure  or similar cloud platforms  Experience presenting to both technical and non-technical audiences and history of publications or presentations at conferences"

# %%
#Change columns to lower case 
df["full_job_description"]=df["full_job_description"].str.lower()

# %%
df["full_job_description"][0]
# Out:
# "combine two of the fastest-growing fields on the planet with a culture of performance  collaboration and opportunity and this is what you get. leading edge technology in an industry that's improving the lives of millions. here  innovation isn't about another gadget  it's about making health care data available wherever and whenever people need it  safely and reliably. there's no room for error. join us and start doing your life's best work.(sm)    the consumer pricing  analytics & reporting team (cpar) within optumrx uses sophisticated algorithms and techniques to understand  quantify and inform our product lines of business  operations and leaders with practical insights for improving their services and operations in support of a world-class optumrx consumer experience. the team uses a blend of scientific  problem solving  and quantitative skills to develop and deliver groundbreaking methods addressing critical problems in our digital environment. the cpar team collaborates across product  design  engineer  and it teams through data science  machine learning  and ai.    do you want to be part of a growing data science and data engineering team that is helping to shape the digital experiences for millions of customers? as a senior data scientist  you will work cross-functionally with other data scientists  analysts  business leaders  and product managers to design  develop  and deploy state-of-the-art models  insights & tools that make a meaningful difference to millions of our customers. you will glean actionable insights from optum’s vast trove of data to translate business problems into predictive models.    this is a unique  high visibility opportunity for someone who wants to have a business impact  dive deep into large-scale data analyses machine learning  reinforcement learning  enable measurable actions and work closely with product and operations teams. this position will report directly to the cpar director. lead and deliver data science solutions leveraging the latest machine learning techniques  including exploratory data analysis  feature engineering  and selection  model selection  evaluation  and cross-validation  a deployment that operationalizes at scale and that drives value to optumrx  research and apply a range of data science methodologies and machine learning models to complex business problems  develop  implement  and maintain tools and algorithms using python and or other languages with appropriate libraries and frameworks  communicate results as well as their uncertainty and limitations effectively to technical and non-technical stakeholders bachelor’s degree in statistics  mathematics  computer science  engineering  or related discipline  3+ years of relevant real-world experience researching  developing  and delivering high impact data-driven insights through machine learning  3+ years of experience using exploratory data analysis  data profiling  and feature engineering on large structured and unstructured datasets  hands-on  demonstrable computer programming skill in sql  python  r  or similar programming language  solid communication skills - ability to succinctly communicate results and tell compelling stories with data to any audience (e.g. presenting findings and deep dives to senior leadership) preferred qualifications  master’s degree in statistics  mathematics  computer science  engineering  or related discipline  deep knowledge of probability  statistics  and machine learning algorithms with the ability to determine when to apply them  deep understanding of supervised and unsupervised machine learning techniques  knowledge of azure  or similar cloud platforms  experience presenting to both technical and non-technical audiences and history of publications or presentations at conferences"

# %%
#Remove stop words
stop_words = stopwords.words('english')
df["full_job_description"] = df["full_job_description"].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
df["full_job_description"][0]
# Out:
# "combine two fastest-growing fields planet culture performance collaboration opportunity get. leading edge technology industry that's improving lives millions. innovation another gadget making health care data available wherever whenever people need safely reliably. there's room error. join us start life's best work.(sm) consumer pricing analytics & reporting team (cpar) within optumrx uses sophisticated algorithms techniques understand quantify inform product lines business operations leaders practical insights improving services operations support world-class optumrx consumer experience. team uses blend scientific problem solving quantitative skills develop deliver groundbreaking methods addressing critical problems digital environment. cpar team collaborates across product design engineer teams data science machine learning ai. want part growing data science data engineering team helping shape digital experiences millions customers? senior data scientist work cross-functionally data scientists analysts business leaders product managers design develop deploy state-of-the-art models insights & tools make meaningful difference millions customers. glean actionable insights optum’s vast trove data translate business problems predictive models. unique high visibility opportunity someone wants business impact dive deep large-scale data analyses machine learning reinforcement learning enable measurable actions work closely product operations teams. position report directly cpar director. lead deliver data science solutions leveraging latest machine learning techniques including exploratory data analysis feature engineering selection model selection evaluation cross-validation deployment operationalizes scale drives value optumrx research apply range data science methodologies machine learning models complex business problems develop implement maintain tools algorithms using python languages appropriate libraries frameworks communicate results well uncertainty limitations effectively technical non-technical stakeholders bachelor’s degree statistics mathematics computer science engineering related discipline 3+ years relevant real-world experience researching developing delivering high impact data-driven insights machine learning 3+ years experience using exploratory data analysis data profiling feature engineering large structured unstructured datasets hands-on demonstrable computer programming skill sql python r similar programming language solid communication skills - ability succinctly communicate results tell compelling stories data audience (e.g. presenting findings deep dives senior leadership) preferred qualifications master’s degree statistics mathematics computer science engineering related discipline deep knowledge probability statistics machine learning algorithms ability determine apply deep understanding supervised unsupervised machine learning techniques knowledge azure similar cloud platforms experience presenting technical non-technical audiences history publications presentations conferences"

# %%
def tokenize_text(text):
    tokens = []
    for sent in nltk.sent_tokenize(text):
        for word in nltk.word_tokenize(sent):
            if len(word) < 2:
                continue
            tokens.append(word.lower())
    return tokens
train_tagged = df.apply(
    lambda r: TaggedDocument(words=tokenize_text(r["full_job_description"]), tags=[r.ID]), axis=1)

# %%
print('corpus of 1st job description')
print(train_tagged[0])
print('********************')
print('BOW count of 1st job descrption')
print(Counter(tokenize_text(df["full_job_description"][0])))
# Out:
# corpus of 1st job description
# TaggedDocument(['combine', 'two', 'fastest-growing', 'fields', 'planet', 'culture', 'performance', 'collaboration', 'opportunity', 'get', 'leading', 'edge', 'technology', 'industry', 'that', "'s", 'improving', 'lives', 'millions', 'innovation', 'another', 'gadget', 'making', 'health', 'care', 'data', 'available', 'wherever', 'whenever', 'people', 'need', 'safely', 'reliably', 'there', "'s", 'room', 'error', 'join', 'us', 'start', 'life', "'s", 'best', 'work', 'sm', 'consumer', 'pricing', 'analytics', 'reporting', 'team', 'cpar', 'within', 'optumrx', 'uses', 'sophisticated', 'algorithms', 'techniques', 'understand', 'quantify', 'inform', 'product', 'lines', 'business', 'operations', 'leaders', 'practical', 'insights', 'improving', 'services', 'operations', 'support', 'world-class', 'optumrx', 'consumer', 'experience', 'team', 'uses', 'blend', 'scientific', 'problem', 'solving', 'quantitative', 'skills', 'develop', 'deliver', 'groundbreaking', 'methods', 'addressing', 'critical', 'problems', 'digital', 'environment', 'cpar', 'team', 'collaborates', 'across', 'product', 'design', 'engineer', 'teams', 'data', 'science', 'machine', 'learning', 'ai', 'want', 'part', 'growing', 'data', 'science', 'data', 'engineering', 'team', 'helping', 'shape', 'digital', 'experiences', 'millions', 'customers', 'senior', 'data', 'scientist', 'work', 'cross-functionally', 'data', 'scientists', 'analysts', 'business', 'leaders', 'product', 'managers', 'design', 'develop', 'deploy', 'state-of-the-art', 'models', 'insights', 'tools', 'make', 'meaningful', 'difference', 'millions', 'customers', 'glean', 'actionable', 'insights', 'optum', 'vast', 'trove', 'data', 'translate', 'business', 'problems', 'predictive', 'models', 'unique', 'high', 'visibility', 'opportunity', 'someone', 'wants', 'business', 'impact', 'dive', 'deep', 'large-scale', 'data', 'analyses', 'machine', 'learning', 'reinforcement', 'learning', 'enable', 'measurable', 'actions', 'work', 'closely', 'product', 'operations', 'teams', 'position', 'report', 'directly', 'cpar', 'director', 'lead', 'deliver', 'data', 'science', 'solutions', 'leveraging', 'latest', 'machine', 'learning', 'techniques', 'including', 'exploratory', 'data', 'analysis', 'feature', 'engineering', 'selection', 'model', 'selection', 'evaluation', 'cross-validation', 'deployment', 'operationalizes', 'scale', 'drives', 'value', 'optumrx', 'research', 'apply', 'range', 'data', 'science', 'methodologies', 'machine', 'learning', 'models', 'complex', 'business', 'problems', 'develop', 'implement', 'maintain', 'tools', 'algorithms', 'using', 'python', 'languages', 'appropriate', 'libraries', 'frameworks', 'communicate', 'results', 'well', 'uncertainty', 'limitations', 'effectively', 'technical', 'non-technical', 'stakeholders', 'bachelor', 'degree', 'statistics', 'mathematics', 'computer', 'science', 'engineering', 'related', 'discipline', '3+', 'years', 'relevant', 'real-world', 'experience', 'researching', 'developing', 'delivering', 'high', 'impact', 'data-driven', 'insights', 'machine', 'learning', '3+', 'years', 'experience', 'using', 'exploratory', 'data', 'analysis', 'data', 'profiling', 'feature', 'engineering', 'large', 'structured', 'unstructured', 'datasets', 'hands-on', 'demonstrable', 'computer', 'programming', 'skill', 'sql', 'python', 'similar', 'programming', 'language', 'solid', 'communication', 'skills', 'ability', 'succinctly', 'communicate', 'results', 'tell', 'compelling', 'stories', 'data', 'audience', 'e.g', 'presenting', 'findings', 'deep', 'dives', 'senior', 'leadership', 'preferred', 'qualifications', 'master', 'degree', 'statistics', 'mathematics', 'computer', 'science', 'engineering', 'related', 'discipline', 'deep', 'knowledge', 'probability', 'statistics', 'machine', 'learning', 'algorithms', 'ability', 'determine', 'apply', 'deep', 'understanding', 'supervised', 'unsupervised', 'machine', 'learning', 'techniques', 'knowledge', 'azure', 'similar', 'cloud', 'platforms', 'experience', 'presenting',  ...
# ********************
# BOW count of 1st job descrption
# Counter({'data': 14, 'learning': 8, 'machine': 7, 'science': 6, 'business': 5, 'engineering': 5, 'team': 4, 'product': 4, 'insights': 4, 'experience': 4, 'deep': 4, "'s": 3, 'millions': 3, 'work': 3, 'cpar': 3, 'optumrx': 3, 'algorithms': 3, 'techniques': 3, 'operations': 3, 'develop': 3, 'problems': 3, 'models': 3, 'statistics': 3, 'computer': 3, 'opportunity': 2, 'improving': 2, 'consumer': 2, 'uses': 2, 'leaders': 2, 'skills': 2, 'deliver': 2, 'digital': 2, 'design': 2, 'teams': 2, 'customers': 2, 'senior': 2, 'tools': 2, 'high': 2, 'impact': 2, 'exploratory': 2, 'analysis': 2, 'feature': 2, 'selection': 2, 'apply': 2, 'using': 2, 'python': 2, 'communicate': 2, 'results': 2, 'technical': 2, 'non-technical': 2, 'degree': 2, 'mathematics': 2, 'related': 2, 'discipline': 2, '3+': 2, 'years': 2, 'programming': 2, 'similar': 2, 'ability': 2, 'presenting': 2, 'knowledge': 2, 'combine': 1, 'two': 1, 'fastest-growing': 1, 'fields': 1, 'planet': 1, 'culture': 1, 'performance': 1, 'collaboration': 1, 'get': 1, 'leading': 1, 'edge': 1, 'technology': 1, 'industry': 1, 'that': 1, 'lives': 1, 'innovation': 1, 'another': 1, 'gadget': 1, 'making': 1, 'health': 1, 'care': 1, 'available': 1, 'wherever': 1, 'whenever': 1, 'people': 1, 'need': 1, 'safely': 1, 'reliably': 1, 'there': 1, 'room': 1, 'error': 1, 'join': 1, 'us': 1, 'start': 1, 'life': 1, 'best': 1, 'sm': 1, 'pricing': 1, 'analytics': 1, 'reporting': 1, 'within': 1, 'sophisticated': 1, 'understand': 1, 'quantify': 1, 'inform': 1, 'lines': 1, 'practical': 1, 'services': 1, 'support': 1, 'world-class': 1, 'blend': 1, 'scientific': 1, 'problem': 1, 'solving': 1, 'quantitative': 1, 'groundbreaking': 1, 'methods': 1, 'addressing': 1, 'critical': 1, 'environment': 1, 'collaborates': 1, 'across': 1, 'engineer': 1, 'ai': 1, 'want': 1, 'part': 1, 'growing': 1, 'helping': 1, 'shape': 1, 'experiences': 1, 'scientist': 1, 'cross-functionally': 1, 'scientists': 1, 'analysts': 1, 'managers': 1, 'deploy': 1, 'state-of-the-art': 1, 'make': 1, 'meaningful': 1, 'difference': 1, 'glean': 1, 'actionable': 1, 'optum': 1, 'vast': 1, 'trove': 1, 'translate': 1, 'predictive': 1, 'unique': 1, 'visibility': 1, 'someone': 1, 'wants': 1, 'dive': 1, 'large-scale': 1, 'analyses': 1, 'reinforcement': 1, 'enable': 1, 'measurable': 1, 'actions': 1, 'closely': 1, 'position': 1, 'report': 1, 'directly': 1, 'director': 1, 'lead': 1, 'solutions': 1, 'leveraging': 1, 'latest': 1, 'including': 1, 'model': 1, 'evaluation': 1, 'cross-validation': 1, 'deployment': 1, 'operationalizes': 1, 'scale': 1, 'drives': 1, 'value': 1, 'research': 1, 'range': 1, 'methodologies': 1, 'complex': 1, 'implement': 1, 'maintain': 1, 'languages': 1, 'appropriate': 1, 'libraries': 1, 'frameworks': 1, 'well': 1, 'uncertainty': 1, 'limitations': 1, 'effectively': 1, 'stakeholders': 1, 'bachelor': 1, 'relevant': 1, 'real-world': 1, 'researching': 1, 'developing': 1, 'delivering': 1, 'data-driven': 1, 'profiling': 1, 'large': 1, 'structured': 1, 'unstructured': 1, 'datasets': 1, 'hands-on': 1, 'demonstrable': 1, 'skill': 1, 'sql': 1, 'language': 1, 'solid': 1, 'communication': 1, 'succinctly': 1, 'tell': 1, 'compelling': 1, 'stories': 1, 'audience': 1, 'e.g': 1, 'findings': 1, 'dives': 1, 'leadership': 1, 'preferred': 1, 'qualifications': 1, 'master': 1, 'probability': 1, 'determine': 1, 'understanding': 1, 'supervised': 1, 'unsupervised': 1, 'azure': 1, 'cloud': 1, 'platforms': 1, 'audiences': 1, 'history': 1, 'publications': 1, 'presentations': 1, 'conferences': 1})

# %% [markdown]
# # Doc2vec Modeling

# %% [markdown]
# ## Building a Vocabulary

# %% [markdown]
# - If dm=0, distributed bag of words (PV-DBOW) is used. if dm=1,‘distributed memory’ (PV-DM) is used
# - dimension feature vectors is 300.
# - negative=5 , specifies how many “noise words” should be drawn
# - hs=0 , and negative is non-zero, negative sampling will be used
# - min_count=2, ignores all words with total frequency lower than this
# - sample=0 , the threshold for configuring which higher-frequency words are randomly down sampled

# %%
model_dbow = Doc2Vec(dm=0, vector_size=300, negative=5, hs=0, min_count=2, sample = 0)
model_dbow.build_vocab([x for x in tqdm(train_tagged)])
# Out:
# 100%|██████████| 275/275 [00:00<00:00, 330970.90it/s]

# %% [markdown]
# ## Training a doc2vec model

# %%
for epoch in range(300):
    model_dbow.train(utils.shuffle([x for x in tqdm(train_tagged)]), total_examples=len(train_tagged), epochs=10)
    model_dbow.alpha -= 0.002
    model_dbow.min_alpha = model_dbow.alpha
# Out:
# 100%|██████████| 275/275 [00:00<00:00, 248210.37it/s]
# 100%|██████████| 275/275 [00:00<00:00, 727259.52it/s]
# 100%|██████████| 275/275 [00:00<00:00, 698204.36it/s]
# 100%|██████████| 275/275 [00:00<00:00, 688206.21it/s]
# 100%|██████████| 275/275 [00:00<00:00, 739854.78it/s]
# 100%|██████████| 275/275 [00:00<00:00, 747042.49it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1045724.03it/s]
# 100%|██████████| 275/275 [00:00<00:00, 142751.68it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1071964.31it/s]
# 100%|██████████| 275/275 [00:00<00:00, 706327.99it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1059167.68it/s]
# 100%|██████████| 275/275 [00:00<00:00, 701601.95it/s]
# 100%|██████████| 275/275 [00:00<00:00, 731410.02it/s]
# 100%|██████████| 275/275 [00:00<00:00, 624152.38it/s]
# 100%|██████████| 275/275 [00:00<00:00, 622468.21it/s]
# 100%|██████████| 275/275 [00:00<00:00, 775156.99it/s]
# 100%|██████████| 275/275 [00:00<00:00, 496100.47it/s]
# 100%|██████████| 275/275 [00:00<00:00, 681295.69it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1098508.19it/s]
# 100%|██████████| 275/275 [00:00<00:00, 679689.81it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1049530.12it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1013562.04it/s]
# 100%|██████████| 275/275 [00:00<00:00, 627206.96it/s]
# 100%|██████████| 275/275 [00:00<00:00, 606113.29it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1075964.18it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1025274.31it/s]
# 100%|██████████| 275/275 [00:00<00:00, 816301.20it/s]
# 100%|██████████| 275/275 [00:00<00:00, 824470.05it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1094339.28it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1095378.54it/s]
# 100%|██████████| 275/275 [00:00<00:00, 957206.31it/s]
# 100%|██████████| 275/275 [00:00<00:00, 726343.58it/s]
# 100%|██████████| 275/275 [00:00<00:00, 588486.53it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1099555.39it/s]
# 100%|██████████| 275/275 [00:00<00:00, 929438.84it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1066019.96it/s]
# 100%|██████████| 275/275 [00:00<00:00, 525482.28it/s]
# 100%|██████████| 275/275 [00:00<00:00, 640085.24it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1115506.38it/s]
# 100%|██████████| 275/275 [00:00<00:00, 712435.82it/s]
# 100%|██████████| 275/275 [00:00<00:00, 725429.94it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1098508.19it/s]
# 100%|██████████| 275/275 [00:00<00:00, 104629.32it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1096419.77it/s]
# 100%|██████████| 275/275 [00:00<00:00, 691921.78it/s]
# 100%|██████████| 275/275 [00:00<00:00, 678490.35it/s]
# 100%|██████████| 275/275 [00:00<00:00, 
/s]
# 100%|██████████| 275/275 [00:00<00:00, 1044776.81it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1039129.37it/s]
# 100%|██████████| 275/275 [00:00<00:00, 704171.92it/s]
# 100%|██████████| 275/275 [00:00<00:00, 742713.20it/s]
# 100%|██████████| 275/275 [00:00<00:00, 791106.72it/s]
# 100%|██████████| 275/275 [00:00<00:00, 701175.44it/s]
# 100%|██████████| 275/275 [00:00<00:00, 803786.48it/s]
# 100%|██████████| 275/275 [00:00<00:00, 1026186.48it/s]
# 100%|██████████| 275/275 [00:00<00:00, 949328.07it/s]

# %%
word_vectors = model_dbow.wv
word_vectors.save(fol_dir+'world_vectors.kv')#save word vectors

# %% [markdown]
# # find the best job

# %%
reloaded_word_vectors = KeyedVectors.load(fol_dir+'world_vectors.kv') #load word vectors

# %%
def pre_process(txt):
  txt=txt.replace('\n',' ')
  txt=txt.replace(',',' ')
  txt=txt.replace('/',' ')

  txt=txt.lower()
  stop_words = stopwords.words('english')
  txt=' '.join([word for word in txt.split() if word not in (stop_words)])
  tokens = []
  for sent in nltk.sent_tokenize(txt):
      for word in nltk.word_tokenize(sent):
          if len(word) < 2:
              continue
          tokens.append(word.lower())
  return(tokens)

# %%
def get_best_matching_job(txt): 
  wmd_arry=[]
  for i in range(len(train_tagged)):
    wmd=reloaded_word_vectors.wmdistance(train_tagged[i].words,pre_process(txt)) #calculate Word Mover’s Distance
    wmd_arry.append(wmd)
  wmd_arry=np.array(wmd_arry)
  indx=np.argmin(wmd_arry)#get index of the job that has the minimmum distance with input txt
  return(df.iloc[indx])

# %%
txt1='Hi, I am Chanaka. I passed my Advanced level examination along with 3 A passes.I am a fresh graduate from the Faculty of Engineering, University of Moratuwa, Sri Lanka. So I am good at mathematical problem-solving and programming. Also, I have 2 years of experience in teaching mathematics for Advanced level students and 3+ years of experience in python programming. Kindly contact me for your projects. I can help you. Thank you.'
print(txt1)
# Out:
# Hi, I am Chanaka. I passed my Advanced level examination along with 3 A passes.I am a fresh graduate from the Faculty of Engineering, University of Moratuwa, Sri Lanka. So I am good at mathematical problem-solving and programming. Also, I have 2 years of experience in teaching mathematics for Advanced level students and 3+ years of experience in python programming. Kindly contact me for your projects. I can help you. Thank you.

# %%
get_best_matching_job(txt1)
# Out:
# ID                                                                        257
# Job Title                   Senior Software Engineer - Telecommute in Mult...
# Description                 Combine two of the fastest-growing fields on t...
# Responsibilities
# Basic Qualifications        Undergraduate degree or equivalent experience\...
# Preferred Qualifications    4+ years of experience writing performance tes...
# full_job_description        combine two fastest-growing fields planet cult...
# Name: 256, dtype: object

# %%
txt2='I am a PMP Certified Project Manager with 9 years of experience in the IT industry, working in various roles such as Technical Project Manager, Business Analyst, and Software Engineer.My expertise is in preparing BRD, FRS, SRS, DFD, Requirement Gathering & Analysis, Statement of Scope, Agile Practices, UML, User stories, Use Case, and Project Management for different IT solutions.'
print(txt2)
# Out:
# I am a PMP Certified Project Manager with 9 years of experience in the IT industry, working in various roles such as Technical Project Manager, Business Analyst, and Software Engineer.My expertise is in preparing BRD, FRS, SRS, DFD, Requirement Gathering & Analysis, Statement of Scope, Agile Practices, UML, User stories, Use Case, and Project Management for different IT solutions.

# %%
get_best_matching_job(txt2)
# Out:
# ID                                                                         57
# Job Title                   Clinical Quality Project Manager - Telecommute...
# Description                 UnitedHealthcare is a company that's on the ri...
# Responsibilities            Provide subject matter expertise in areas incl...
# Basic Qualifications        Undergraduate Degree (or higher)\n2+ years of ...
# Preferred Qualifications    PMP Certification\nCPHQ Certification\nLean Si...
# full_job_description        unitedhealthcare company that's rise. we're ex...
# Name: 56, dtype: object

# %%
print(df["full_job_description"][1])
# Out:
# unitedhealthcare company that's rise. we're expanding multiple directions across borders way think. innovation another gadget transforming health care industry. ready make difference? make home us start life's best work.(sm) uhc advanced research analytics (ara) organization provides data-driven insights builds advanced ai ml solutions various lines business shared services organizations within unitedhealthcare. ara team partners various entities within enterprise increase operational value optimize experience lower healthcare costs. ara team serves across wide variety business domains including claims processing payment integrity (fraud waste abuse error) consumer experience (omnichannel customer service campaigns net promoter scores) provider service models many more. senior principal data scientist role work within transactions analytics automation domain develop transformative solutions lead effective decision-making efficient execution across multiple lines business. role specifically focuses supporting claim operations teams throughout unitedhealthcare efforts streamline processes reduce waste due rework appeals. located willing work within eastern time zone central time zone hours flexibility telecommute* take tough challenges. work vast amounts data multiple sources deliver high-impact actionable insights senior leadership business operations; enable data-driven decision-making across enterprise improve efficiency effectiveness uhc operations perform exploratory data analysis structured unstructured diverse datasets; apply knowledge statistics machine learning programming data modeling simulation advanced mathematics recognize patterns identify opportunities pose business questions make valuable discoveries leading prototype development product improvement make presentations sr. executives decision-makers serve thought leader transactions analytics domain. provide expert advisory services benefit operations strategy metrics product development analytics vision senior leadership partner various functions produce innovative transformative data science solutions directly contribute achieving enterprise goals vision build relationships drive awareness knowledge advanced analytics promoting capability areas advanced research & analytics team serve subject matter expert data science dealing specifically medical claim data utilized created 10+ years experience working data science initiatives corporate environment 5+ years hands-on experience data analysis data-driven investigations data storytelling visualizations analytic insight creation executive consumption experience handling terabyte size datasets diving data discover hidden patterns using data visualization tools experience r python advanced proficiency sql advanced proficiency excel sound business focus; must excel connecting business requirements analytic objectives measurable business benefit experience extracting data enterprise data warehouses enterprise data lakes knowledge experience analyzing medical claim data well standard processes generate data health care claim adjudication process. work within est cst hours master’s degree higher highly quantitative field experience spark experience cloud based analytic services experience following: machine learning platforms data mart development engineering advanced statistics natural language processing optical character recognition process mining highly experienced data visualization tools tableau; powerbi

# %%
get_best_matching_job(df["full_job_description"][1])
# Out:
# ID                                                                          2
# Job Title                   Senior Principal Data Scientist - Telecommute ...
# Description                 UnitedHealthcare is a company that's on the ri...
# Responsibilities            Work with vast amounts of data from multiple s...
# Basic Qualifications        10+ years of experience working on data scienc...
# Preferred Qualifications    Master’s Degree or higher in a highly quantita...
# full_job_description        unitedhealthcare company that's rise. we're ex...
# Name: 1, dtype: object
